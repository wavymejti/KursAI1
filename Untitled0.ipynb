# %% [markdown]
# <a href="https://colab.research.google.com/github/wavymejti/KursAI1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
pusta_lista = []
pusta_krotka = ()

print("rozmiar pustej listy w bajtach", sys.getsizeof(pusta_lista))
print("rozmiar pustej krotki w bajtach", sys.getsizeof(pusta_krotka))
# Out:
# rozmiar pustej listy w bajtach 56
# rozmiar pustej krotki w bajtach 40
